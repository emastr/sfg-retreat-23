# %% [markdown]
# ## Ideas
#
# * Name is too long, shut down, prove why the name is
# relevant by proving that all the different areas are useful in a problem.
#
#
# * Sent an email with wrong answer, change problem so the answer is still the same.
# Go back in time and solve backwards to change the problem. Which will fail everyone else.
# Out on a coffee break. Solve within 30 minutes, ask for help to do it faster.
#
# * Smudge a cake, and reconstruct. There was a message
#
# * Reveal the next clue by solution
#
# * Low wavenumber message is the actual message
# * Noisy message superimposed filter out high frequencies
# * Encourage collaboration
# * Data in a usb
# * Jupyter notebook
# * Scavenger hunt
# * Small steps along the way to answer math questions
#
#
# * Number of participants 35
# * 6 groups of 5
# * numerics PhD + opt Prof / numerics Prof + opt PhD
# * Questions in weird units
# * Answer "correctly" to get the solver
# * Before and After Shirts - Get shirts
# * Send pictures of research and make a nice logo
#
#
# * Math + Logic = Magic?
# * It's the Process that Matters
# * Who's birthday is it? -> senior department person
# * Division Fika
# * Optim group  +  Simul group = get closer together
#   * Optim has Fika on Thursday
#   * Simul has Fika on Friday
#     * Optim group got a cake from someone in Simul,
#     * message smudged "Can we Join?"
# * "Elevator is too slow"
# * Someone wrote down on the whiteboard
#   * Wrote it down with a permanent marker
#   * Person who wrote it down has mysteriously disappeared
#   * " best coffee @ mech"
#   *
#
#
# Durett Book - theorem about this?
# Viktor's Approach:
# * Can i move inside integral sign
# * Family of things that this needs to hold for
# * Signal is the only moving part
# * Prove it for one signal, is it obvious then?
