# %%
import sys
sys.path.append('../')
sys.path.append("/home/emastr/phd/")

import numpy as np
from secret.spectral_solve import *
from secret.function_tools import *
from matplotlib import image as im
from util.basis_scaled import ScaleShiftedBasis, BasisProduct, FourBasis

# %%
init = load_init_state(K=129)

plt.figure(figsize = (20,10))
plt.subplot(1,2,1)
init.change_dim(257, 257).plot(plt.gca(), cmap='gray')

# %%
bx, by = velocity_field()
g = lambda x,y: init(x.flatten(), y.flatten()).reshape(y.shape)# (dist(x%1-0.5,y%1-0.5) < 0.3) #np.exp(np.sin(2 * np.pi * x) + np.sin(2 * np.pi * y))

N_print = 16
N = N_print * 200 + 1

def save_callback(u_four, t, n):
    """Save the solution at time t, and the time t itself."""
    if n % (N // N_print) == 0:
        u_vec.append(invFourier2D(u_four))
        print(f"t = {t:.2f}, [{n}/{N} = {int(n/N * 100)}% done], ", end="\r")


lam = 0.00005

# %%
x = np.linspace(0,1,100)
y = np.linspace(0,1,100)
X, Y = np.meshgrid(x, y)
v_analytic = get_sol_analytic(g, lambda x,y: w(x, y), 1)
v_reverse = get_sol_analytic(v_analytic, lambda x,y: -w(x, y), 1)
v = v_analytic(X, Y)
vBlock = np.vstack([np.hstack([v,v,v]), np.hstack([v,v,v]), np.hstack([v,v,v])])
plt.figure(figsize=(15,15))
plt.imshow(vBlock, cmap="gray")#, vmin=0., vmax=7., cmap="inferno")
plt.xlim([0.8*v.shape[0], 2.2*v.shape[0]])
plt.ylim([0.8*v.shape[0], 2.2*v.shape[0]])
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> v_analytic = get_sol_analytic(g, lambda x,y: w(x, y), 1)
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> v_reverse = get_sol_analytic(v_analytic, lambda x,y: -w(x, y), 1)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> v = v_analytic(X, Y)
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> vBlock = np.vstack([np.hstack([v,v,v]), np.hstack([v,v,v]), np.hstack([v,v,v])])
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> plt.figure(figsize=(15,15))
#
# File ~/phd/projects/sfg-retreat-23/secret/spectral_solve.py:23, in get_sol_analytic.<locals>.uT(x, y)
#      22 def uT(x, y):
# ---> 23     theta = w(x, y) * T
#      24     return u0((x-0.5) * np.cos(theta) - (y-0.5) * np.sin(theta)+0.5,
#      25               (x-0.5) * np.sin(theta) + (y-0.5) * np.cos(theta)+0.5)
#
# /home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> y = np.linspace(0,1,100)
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> X, Y = np.meshgrid(x, y)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> v_analytic = get_sol_analytic(g, lambda x,y: w(x, y), 1)
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> v_reverse = get_sol_analytic(v_analytic, lambda x,y: -w(x, y), 1)
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> v = v_analytic(X, Y)
#
# NameError: name 'w' is not defined

# %%
print(f"CFL condition: {N / K**2}")
solve(g, f, bx, by, lam, N, 1, K, callback=save_callback)
v1, v0 =  u_vec[-1], u_vec[0]
# Out:
# CFL condition: 0.07923071211108636
# t = 1.00, [3200/3201 = 99% done],

# %%
v = v1
vBlock = np.vstack([np.hstack([v,v,v]), np.hstack([v,v,v]), np.hstack([v,v,v])])
plt.figure(figsize=(15,15))
plt.imshow(vBlock, cmap="gray")#, vmin=0., vmax=7., cmap="inferno")
plt.xlim([0.8*v.shape[0], 2.2*v.shape[0]])
plt.ylim([0.8*v.shape[0], 2.2*v.shape[0]])
plt.axis("off")
# Out:
# (160.8, 442.20000000000005, 160.8, 442.20000000000005)

# %%
coef = BasisProduct._interpolate(u_vec[-1], FourBasis, FourBasis)
basis2 = BasisProduct(coef, coef.shape[0], coef.shape[1], FourBasis, FourBasis)
basis2 = basis.change_dim(K, K)

v = get_sol_analytic(lambda x,y: basis2(x.flatten(), y.flatten()).reshape(y.shape), lambda x,y: -w(x, y), 1)(X, Y)
vBlock = np.vstack([np.hstack([v,v,v]), np.hstack([v,v,v]), np.hstack([v,v,v])])
plt.figure(figsize=(15,15))
plt.imshow(vBlock, cmap="gray")#, vmin=0., vmax=7., cmap="inferno")
plt.xlim([0.8*v.shape[0], 2.2*v.shape[0]])
plt.ylim([0.8*v.shape[0], 2.2*v.shape[0]])
plt.axis("off")
# Out:
# (80.0, 220.00000000000003, 80.0, 220.00000000000003)

# %% [markdown]
# ### RUN BACKWARDS

# %%
assert False
coef = BasisProduct._interpolate(v1, FourBasis, FourBasis)
basis = BasisProduct(coef, coef.shape[0], coef.shape[1], FourBasis, FourBasis)
basis = basis.change_dim(K, K)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> assert False
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> coef = BasisProduct._interpolate(v1, FourBasis, FourBasis)
#       <a href='vscode-notebook-cell://ssh-remote%2Bshepp.math.kth.se/home/emastr/phd/projects/sfg-retreat-23/retreat_question.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> basis = BasisProduct(coef, coef.shape[0], coef.shape[1], FourBasis, FourBasis)
#
# AssertionError:

# %%
t_vec = []
u_vec = []
N = N_plot * 200 + 1

def save_callback(u_four, t, n):
    """Save the solution at time t, and the time t itself."""
    if n % (N // N_plot) == 0:
        t_vec.append(t)
        u_vec.append(invFourier2D(u_four))
        print(f"t = {t:.2f}, [{n}/{N} = {int(n/N * 100)}% done], ", end="\r")
        
lam = 0.00002
g = lambda x,y: basis.change_dim(K, K).eval_grid()# (dist(x%1-0.5,y%1-0.5) < 0.3) #np.exp(np.sin(2 * np.pi * x) + np.sin(2 * np.pi * y))
bx_rev = lambda x, y: -bx(x, y)  # 3 is nice setting for the test
by_rev = lambda x, y: -by(x, y)

print(f"CFL condition: {N / K**2}")
solve(g, f, bx_rev, by_rev, lam, N, 1, K, callback=save_callback)
v1, v0 =  u_vec[-1], u_vec[0]
# Out:
# CFL condition: 0.07923071211108636
# t = 0.19, [600/3201 = 18% done],
# t = 1.00, [3200/3201 = 99% done],

# %%
plt.figure(figsize=(15,15))
plt.imshow(v1[:, ::-1].T, cmap="gray")

# %% [markdown]
# ## Gradient Descent with Low Resolution Solver

# %%
def solve_low(u0):
    N_plot = 16
    K = 101
    N = N_plot * 500 + 1
    coef = BasisProduct._interpolate(v1, FourBasis, FourBasis)
    basis = BasisProduct(coef, coef.shape[0], coef.shape[1], FourBasis, FourBasis)
    basis = basis.change_dim(K, K)

    g = lambda x,y: basis.change_dim(K, K).eval_grid()
    
    def save_callback(u_four, t, n):
        """Save the solution at time t, and the time t itself."""
        if n % (N // N_plot) == 0:
            print(f"t = {t:.2f}, [{n}/{N} = {int(n/N * 100)}% done], ", end="\r")
            
    lam = 0.00004
    
    print(f"CFL condition: {N / K**2}")
    out = solve(g, f, bx_rev, by_rev, lam, N, 1, K, callback=save_callback)
    return out

vend = solve_low(v0[:, ::-1].T)


plt.figure(figsize=(15,15))
plt.imshow(vend, cmap="gray")
# Out:
# CFL condition: 0.7843348691304775
# t = 0.19, [1500/8001 = 18% done],
# t = 1.00, [8000/8001 = 99% done],
